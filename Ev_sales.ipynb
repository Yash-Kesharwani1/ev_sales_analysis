# %%
import pandas as pd
ev_makers = pd.read_csv('datasets/electric_vehicle_sales_by_makers.csv')
ev_states = pd.read_csv('datasets/electric_vehicle_sales_by_state.csv')
dim_date = pd.read_csv('datasets/dim_date.csv')

# %%
ev_makers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    816 non-null    object
#  1   vehicle_category        816 non-null    object
#  2   maker                   816 non-null    object
#  3   electric_vehicles_sold  816 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 25.6+ KB

# %%
ev_states.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2445 entries, 0 to 2444
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    2445 non-null   object
#  1   state                   2445 non-null   object
#  2   vehicle_category        2445 non-null   object
#  3   electric_vehicles_sold  2445 non-null   int64
#  4   total_vehicles_sold     2445 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 95.6+ KB

# %%
dim_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         36 non-null     object
#  1   fiscal_year  36 non-null     int64
#  2   quarter      36 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 996.0+ bytes

# %% [markdown]
# # In dataset there is no null value in any column

# %%
ev_makers
# Out:
#           date vehicle_category            maker  electric_vehicles_sold
# 0    01-Apr-21       2-Wheelers     OLA ELECTRIC                       0
# 1    01-Apr-22       2-Wheelers         OKAYA EV                       0
# 2    01-May-21       2-Wheelers     OLA ELECTRIC                       0
# 3    01-Jun-21       2-Wheelers     OLA ELECTRIC                       0
# 4    01-Jul-21       2-Wheelers     OLA ELECTRIC                       0
# ..         ...              ...              ...                     ...
# 811  01-Mar-24       2-Wheelers           BGAUSS                    3070
# 812  01-Mar-24       2-Wheelers  BATTRE ELECTRIC                     625
# 813  01-Mar-24       2-Wheelers    KINETIC GREEN                    3915
# 814  01-Mar-24       2-Wheelers           REVOLT                     585
# 815  01-Mar-24       2-Wheelers           OTHERS                   10579
#
# [816 rows x 4 columns]

# %%
ev_states
# Out:
#            date                     state vehicle_category  \
# 0     01-Apr-21                    Sikkim       2-Wheelers
# 1     01-Apr-21                    Sikkim       4-Wheelers
# 2     01-May-21                    Sikkim       2-Wheelers
# 3     01-May-21                    Sikkim       4-Wheelers
# 4     01-Jun-21                    Sikkim       2-Wheelers
# ...         ...                       ...              ...
# 2440  01-Mar-24                   Mizoram       2-Wheelers
# 2441  01-Mar-24                DNH and DD       2-Wheelers
# 2442  01-Mar-24                   Manipur       2-Wheelers
# 2443  01-Mar-24  Andaman & Nicobar Island       2-Wheelers
# 2444  01-Mar-24                  Nagaland       2-Wheelers
#
#       electric_vehicles_sold  total_vehicles_sold
# 0                          0                  398
# 1                          0                  361
# 2                          0                  113
# 3                          0                   98
# ...

# %%
dim_date.sort_values(by='date')
# Out:
#          date  fiscal_year quarter
# 0   01-Apr-21         2022      Q1
# 12  01-Apr-22         2023      Q1
# 24  01-Apr-23         2024      Q1
# 4   01-Aug-21         2022      Q2
# 16  01-Aug-22         2023      Q2
# 28  01-Aug-23         2024      Q2
# 8   01-Dec-21         2022      Q3
# 20  01-Dec-22         2023      Q3
# 32  01-Dec-23         2024      Q3
# 10  01-Feb-22         2022      Q4
# 22  01-Feb-23         2023      Q4
# 34  01-Feb-24         2024      Q4
# 9   01-Jan-22         2022      Q4
# 21  01-Jan-23         2023      Q4
# 33  01-Jan-24         2024      Q4
# 3   01-Jul-21         2022      Q2
# 15  01-Jul-22         2023      Q2
# 27  01-Jul-23         2024      Q2
# 2   01-Jun-21         2022      Q1
# 14  01-Jun-22         2023      Q1
# 26  01-Jun-23         2024      Q1
# 11  01-Mar-22         2022      Q4
# 23  01-Mar-23         2023      Q4
# 35  01-Mar-24         2024      Q4
# 1   01-May-21         2022      Q1
# 13  01-May-22         2023      Q1
# ...

# %%
dim_date['date'] = pd.to_datetime(dim_date['date'])
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_7588\233481823.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dim_date['date'] = pd.to_datetime(dim_date['date'])

# %%
dim_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         36 non-null     datetime64[ns]
#  1   fiscal_year  36 non-null     int64
#  2   quarter      36 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 996.0+ bytes

# %%
ev_states['date'] = pd.to_datetime(ev_states['date'])
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_7588\919104686.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ev_states['date'] = pd.to_datetime(ev_states['date'])

# %%
ev_states.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2445 entries, 0 to 2444
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    2445 non-null   datetime64[ns]
#  1   state                   2445 non-null   object
#  2   vehicle_category        2445 non-null   object
#  3   electric_vehicles_sold  2445 non-null   int64
#  4   total_vehicles_sold     2445 non-null   int64
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 95.6+ KB

# %%
ev_makers['date'] = pd.to_datetime(ev_makers['date'])
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_7588\4082904982.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ev_makers['date'] = pd.to_datetime(ev_makers['date'])

# %%
ev_makers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    816 non-null    datetime64[ns]
#  1   vehicle_category        816 non-null    object
#  2   maker                   816 non-null    object
#  3   electric_vehicles_sold  816 non-null    int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 25.6+ KB

# %% [markdown]
# # Changed the datatype of date column of all tables

# %%
print(ev_makers['date'].unique())
# Out:
# <DatetimeArray>
# ['2021-04-01 00:00:00', '2022-04-01 00:00:00', '2021-05-01 00:00:00',
#  '2021-06-01 00:00:00', '2021-07-01 00:00:00', '2021-08-01 00:00:00',
#  '2021-09-01 00:00:00', '2021-10-01 00:00:00', '2021-11-01 00:00:00',
#  '2022-05-01 00:00:00', '2022-06-01 00:00:00', '2022-07-01 00:00:00',
#  '2022-08-01 00:00:00', '2022-09-01 00:00:00', '2022-10-01 00:00:00',
#  '2022-11-01 00:00:00', '2021-12-01 00:00:00', '2022-12-01 00:00:00',
#  '2022-01-01 00:00:00', '2023-01-01 00:00:00', '2022-02-01 00:00:00',
#  '2023-02-01 00:00:00', '2022-03-01 00:00:00', '2023-04-01 00:00:00',
#  '2023-05-01 00:00:00', '2023-06-01 00:00:00', '2023-07-01 00:00:00',
#  '2023-08-01 00:00:00', '2023-09-01 00:00:00', '2023-10-01 00:00:00',
#  '2023-11-01 00:00:00', '2023-12-01 00:00:00', '2024-01-01 00:00:00',
#  '2024-02-01 00:00:00', '2023-03-01 00:00:00', '2024-03-01 00:00:00']
# Length: 36, dtype: datetime64[ns]

# %% [markdown]
# ## We have the data from the date April-2021 to March-2024

# %%
ev_makers['month'] = pd.DatetimeIndex(ev_makers['date']).month

# %%
ev_states['month'] = pd.DatetimeIndex(ev_states['date']).month

# %% [markdown]
# ## Created a column of month in both ev_makers and ev_states

# %%
ev_makers['year'] = pd.DatetimeIndex(ev_makers['date']).year

# %%
ev_states['year'] = pd.DatetimeIndex(ev_states['date']).year

# %% [markdown]
# ## Created a column of month in both ev_makers and ev_states

# %%
ev_makers['quarter'] = pd.cut(ev_makers['month'], [0,3,6,9,12], labels = ['Q4','Q1','Q2','Q3'])

# %%
ev_states['quarter'] = pd.cut(ev_states['month'], [0,3,6,9,12], labels = ['Q4','Q1','Q2','Q3'])

# %%
ev_makers
# Out:
#           date vehicle_category            maker  electric_vehicles_sold  \
# 0   2021-04-01       2-Wheelers     OLA ELECTRIC                       0
# 1   2022-04-01       2-Wheelers         OKAYA EV                       0
# 2   2021-05-01       2-Wheelers     OLA ELECTRIC                       0
# 3   2021-06-01       2-Wheelers     OLA ELECTRIC                       0
# 4   2021-07-01       2-Wheelers     OLA ELECTRIC                       0
# ..         ...              ...              ...                     ...
# 811 2024-03-01       2-Wheelers           BGAUSS                    3070
# 812 2024-03-01       2-Wheelers  BATTRE ELECTRIC                     625
# 813 2024-03-01       2-Wheelers    KINETIC GREEN                    3915
# 814 2024-03-01       2-Wheelers           REVOLT                     585
# 815 2024-03-01       2-Wheelers           OTHERS                   10579
#
#      month  year quarter
# 0        4  2021      Q1
# 1        4  2022      Q1
# ...

# %%
filtered_ev_makers_top_2023 = ev_makers[(ev_makers['vehicle_category'] == '2-Wheelers') & (ev_makers['year'] == 2023)]

# %%
filtered_ev_makers_top_2023.sort_values(by='electric_vehicles_sold', ascending=False).head(3)
# Out:
#           date vehicle_category         maker  electric_vehicles_sold  month  \
# 689 2023-12-01       2-Wheelers  OLA ELECTRIC                   30588     12
# 651 2023-11-01       2-Wheelers  OLA ELECTRIC                   29980     11
# 429 2023-05-01       2-Wheelers  OLA ELECTRIC                   29447      5
#
#      year quarter
# 689  2023      Q3
# 651  2023      Q3
# 429  2023      Q1

# %% [markdown]
# ## Top 3 by electric_vehicles_sold of year 2023

# %%
filtered_ev_makers_top_2024 = ev_makers[(ev_makers['vehicle_category'] == '2-Wheelers') & (ev_makers['year'] == 2024)]

# %%
filtered_ev_makers_top_2024.sort_values(by='electric_vehicles_sold', ascending=False).head(3)
# Out:
#           date vehicle_category         maker  electric_vehicles_sold  month  \
# 803 2024-03-01       2-Wheelers  OLA ELECTRIC                   44630      3
# 765 2024-02-01       2-Wheelers  OLA ELECTRIC                   33967      2
# 727 2024-01-01       2-Wheelers  OLA ELECTRIC                   32275      1
#
#      year quarter
# 803  2024      Q4
# 765  2024      Q4
# 727  2024      Q4

# %% [markdown]
# ## Top 3 by electric_vehicles_sold of year 2023

# %%
filtered_ev_makers_bottom_2023 = ev_makers[(ev_makers['vehicle_category'] == '2-Wheelers') & (ev_makers['year'] == 2023)]

# %%
filtered_ev_makers_bottom_2023.sort_values(by='electric_vehicles_sold', ascending=False).tail(3)
# Out:
#           date vehicle_category            maker  electric_vehicles_sold  \
# 475 2023-06-01       2-Wheelers  BATTRE ELECTRIC                      82
# 760 2023-02-01       2-Wheelers           REVOLT                      79
# 722 2023-01-01       2-Wheelers           REVOLT                      14
#
#      month  year quarter
# 475      6  2023      Q1
# 760      2  2023      Q4
# 722      1  2023      Q4

# %% [markdown]
# ## Bottom 3 by electric_vehicles_sold of year 2023

# %%
filtered_ev_makers_bottom_2024 = ev_makers[(ev_makers['vehicle_category'] == '2-Wheelers') & (ev_makers['year'] == 2024)]

# %%
filtered_ev_makers_bottom_2024.sort_values(by='electric_vehicles_sold', ascending=False).tail(3)
# Out:
#           date vehicle_category            maker  electric_vehicles_sold  \
# 809 2024-03-01       2-Wheelers    HERO ELECTRIC                     316
# 736 2024-01-01       2-Wheelers  BATTRE ELECTRIC                     284
# 774 2024-02-01       2-Wheelers  BATTRE ELECTRIC                     219
#
#      month  year quarter
# 809      3  2024      Q4
# 736      1  2024      Q4
# 774      2  2024      Q4

# %% [markdown]
# ## Bottom 3 by electric_vehicles_sold of year 2024

# %% [markdown]
# # Question 01:-
# # top 3 and bottom 3 makers for the fiscal years 2023 and 2024 in terms of the number of 2-wheelers sold.

# %%
ev_states['penetration_rate'] = (ev_states['electric_vehicles_sold']/ev_states['total_vehicles_sold']) * 100

# %%
ev_states.sort_values(by='penetration_rate',ascending=False)
# Out:
#            date                     state vehicle_category  \
# 1368 2024-01-01                    Kerala       4-Wheelers
# 2067 2023-03-01                Chandigarh       2-Wheelers
# 2383 2024-01-01                    Ladakh       2-Wheelers
# 2432 2024-03-01                       Goa       2-Wheelers
# 1605 2021-10-01                    Ladakh       2-Wheelers
# ...         ...                       ...              ...
# 319  2022-08-01  Andaman & Nicobar Island       4-Wheelers
# 320  2022-08-01         Arunachal Pradesh       2-Wheelers
# 321  2022-08-01         Arunachal Pradesh       4-Wheelers
# 322  2022-08-01                    Ladakh       2-Wheelers
# 0    2021-04-01                    Sikkim       2-Wheelers
#
#       electric_vehicles_sold  total_vehicles_sold  month  year quarter  \
# 1368                     734                  164      1  2024      Q4
# 2067                     362                  663      3  2023      Q4
# ...

# %%
df = ev_states.copy()

# %%
import pandas as pd

# Assuming your DataFrame is named df

# Step 2: Filter the data for the years 2022 and 2024
df_filtered = df[df['year'].isin([2022, 2024])]

# Step 3: Group the data by state and year to get the average penetration rate for each state in those years
avg_penetration_rate = df_filtered.groupby(['state', 'year'])['penetration_rate'].mean().reset_index()

# Step 4: Pivot the table to have years as columns for easier comparison
pivot_table = avg_penetration_rate.pivot(index='state', columns='year', values='penetration_rate').reset_index()

# Step 5: Identify the states with a decline in penetration rate
pivot_table['decline'] = pivot_table[2024] < pivot_table[2022]
states_with_decline = pivot_table[pivot_table['decline'] == True]['state'].tolist()

states_with_decline
# Out:
# []

# %%
# Step 2: Filter the data for the years 2022 and 2024
df_filtered = df[df['year'].isin([2022, 2024])]

# %%
df_filtered
# Out:
#            date                     state vehicle_category  \
# 18   2022-01-01                    Sikkim       2-Wheelers
# 19   2022-01-01                    Sikkim       4-Wheelers
# 20   2022-02-01                    Sikkim       2-Wheelers
# 21   2022-02-01                    Sikkim       4-Wheelers
# 22   2022-03-01                    Sikkim       2-Wheelers
# ...         ...                       ...              ...
# 2440 2024-03-01                   Mizoram       2-Wheelers
# 2441 2024-03-01                DNH and DD       2-Wheelers
# 2442 2024-03-01                   Manipur       2-Wheelers
# 2443 2024-03-01  Andaman & Nicobar Island       2-Wheelers
# 2444 2024-03-01                  Nagaland       2-Wheelers
#
#       electric_vehicles_sold  total_vehicles_sold  month  year quarter  \
# 18                         0                  400      1  2022      Q4
# 19                         0                  270      1  2022      Q4
# ...

# %%
# Step 3: Group the data by state and year to get the average penetration rate for each state in those years
avg_penetration_rate = df_filtered.groupby(['state', 'year'])['penetration_rate'].mean().reset_index()

# %%
print(avg_penetration_rate)
# Out:
#                        state  year  penetration_rate
# 0          Andaman & Nicobar  2024          0.207039
# 1   Andaman & Nicobar Island  2022          0.352978
# 2   Andaman & Nicobar Island  2024          0.672477
# 3             Andhra Pradesh  2022          2.590026
# 4             Andhra Pradesh  2024          4.566529
# ..                       ...   ...               ...
# 64             Uttar Pradesh  2024          2.181659
# 65               Uttarakhand  2022          2.163515
# 66               Uttarakhand  2024          2.529881
# 67               West Bengal  2022          0.974137
# 68               West Bengal  2024          2.876506
#
# [69 rows x 3 columns]

# %%
# Step 4: Pivot the table to have years as columns for easier comparison
pivot_table = avg_penetration_rate.pivot(index='state', columns='year', values='penetration_rate').reset_index()

# %%
pivot_table
# Out:
# year                     state      2022       2024
# 0            Andaman & Nicobar       NaN   0.207039
# 1     Andaman & Nicobar Island  0.352978   0.672477
# 2               Andhra Pradesh  2.590026   4.566529
# 3            Arunachal Pradesh  0.008904   0.142707
# 4                        Assam  0.316513   0.724978
# 5                        Bihar  0.656718   1.531642
# 6                   Chandigarh  2.465233   8.818153
# 7                 Chhattisgarh  2.513785   4.306601
# 8                   DNH and DD  0.600840   1.948993
# 9                        Delhi  6.344228   7.799838
# 10                         Goa  6.962570  14.724136
# 11                     Gujarat  3.441506   4.448281
# 12                     Haryana  1.663343   2.091631
# 13            Himachal Pradesh  0.798823   0.911592
# 14           Jammu and Kashmir  1.378591   2.508129
# 15                   Jharkhand  0.997117   1.449940
# 16                   Karnataka  4.815632   8.904956
# ...

# %%
# Step 5: Identify the states with a decline in penetration rate
pivot_table['decline'] = pivot_table[2024] < pivot_table[2022]
states_with_decline = pivot_table[pivot_table['decline'] == True]['state'].tolist()

# %%
pivot_table
# Out:
# year                     state      2022       2024  decline
# 0            Andaman & Nicobar       NaN   0.207039    False
# 1     Andaman & Nicobar Island  0.352978   0.672477    False
# 2               Andhra Pradesh  2.590026   4.566529    False
# 3            Arunachal Pradesh  0.008904   0.142707    False
# 4                        Assam  0.316513   0.724978    False
# 5                        Bihar  0.656718   1.531642    False
# 6                   Chandigarh  2.465233   8.818153    False
# 7                 Chhattisgarh  2.513785   4.306601    False
# 8                   DNH and DD  0.600840   1.948993    False
# 9                        Delhi  6.344228   7.799838    False
# 10                         Goa  6.962570  14.724136    False
# 11                     Gujarat  3.441506   4.448281    False
# 12                     Haryana  1.663343   2.091631    False
# 13            Himachal Pradesh  0.798823   0.911592    False
# ...

# %%
states_with_decline
# Out:
# []

# %% [markdown]
# # Question 03:-
# # From this we can say that
# ## There is no state with negative penetration rate i.e. in each state the sales of electric vehicle increases yearly form 2022 to 2024

# %%
# Top 5 sellers
ev_makers['maker'].unique()
# Out:
# array(['OLA ELECTRIC', 'OKAYA EV', 'BYD India', 'PCA Automobiles',
#        'BMW India', 'Volvo Auto India', 'KIA Motors', 'Mercedes -Benz AG',
#        'Tata Motors', 'MG Motor', 'Mahindra & Mahindra', 'Hyundai Motor',
#        'HERO ELECTRIC', 'OKINAWA', 'AMPERE', 'ATHER', 'PURE EV', 'TVS',
#        'REVOLT', 'BAJAJ', 'BEING', 'JITENDRA', 'OTHERS', 'BGAUSS',
#        'BATTRE ELECTRIC', 'KINETIC GREEN'], dtype=object)

# %%
df2 = ev_makers.copy()

# %%
# Step 2: Filter the data for the years 2022, 2023 and 2024
df2_filtered = df2[df2['year'].isin([2022, 2023, 2024])]

# %%
df2_filtered = df2_filtered[df2_filtered['vehicle_category']=='4-Wheelers']

# %%
df2_filtered['vehicle_category'].unique()
# Out:
# array(['4-Wheelers'], dtype=object)

# %%
# Step 3: Group the data by state and year to get the average penetration rate for each state in those years
sum_of_vehicle_sold = df2_filtered.groupby(['maker', 'year'])['electric_vehicles_sold'].sum().sort_values(ascending=False).reset_index()

# %%
sum_of_vehicle_sold
# Out:
#                   maker  year  electric_vehicles_sold
# 0           Tata Motors  2023                   40348
# 1   Mahindra & Mahindra  2023                   26273
# 2           Tata Motors  2022                   24352
# 3           Tata Motors  2024                   17361
# 4   Mahindra & Mahindra  2022                   10215
# 5              MG Motor  2023                    7153
# 6              MG Motor  2024                    2622
# 7              MG Motor  2022                    2484
# 8   Mahindra & Mahindra  2024                    2316
# 9             BYD India  2023                    1689
# 10      PCA Automobiles  2023                    1467
# 11        Hyundai Motor  2023                    1207
# 12            BMW India  2023                     984
# 13        Hyundai Motor  2022                     447
# 14     Volvo Auto India  2023                     427
# 15            BYD India  2024                     400
# ...

# %%
# Step 3: Pivot the table to have years as columns for easier comparison
pivot_table = sum_of_vehicle_sold.pivot(index='maker', columns='year', values='electric_vehicles_sold').reset_index()

# %%
pivote_table = pivot_table.fillna(0)

# %%
pivote_table['total_sales']=pivote_table[2022]+pivote_table[2023]+pivote_table[2024]

# %%
pivote_table.sort_values(by=2022,ascending=False)
# Out:
# year                maker   2022   2023   2024  total_sales
# 8             Tata Motors  24352  40348  17361        82061
# 5     Mahindra & Mahindra  10215  26273   2316        38804
# 4                MG Motor   2484   7153   2622        12259
# 2           Hyundai Motor    447   1207    338         1992
# 1               BYD India    329   1689    400         2418
# 3              KIA Motors    155    330     72          557
# 0               BMW India    118    984    268         1370
# 6       Mercedes -Benz AG     45    243     84          372
# 9        Volvo Auto India     25    427    116          568
# 7         PCA Automobiles      0   1467    217         1684

# %% [markdown]
# ### Top 5 ev sallers are Tata Motors, Mahindra & Mahindra, MG Motor, Hyundai Motor, BYD India, for year 2022
# ### Top 5 ev sallers are Tata Motors, Mahindra & Mahindra, MG Motor, BYD India, PCA Automobiles for year 2024
# ### Top 5 ev sallers are Tata Motors, MG Motor, Mahindra & Mahindra, BYD India, Hyundai Motor for year 2024
# ### Top 5 ev sallers are Tata Motors, Mahindra & Mahindra, MG Motor, BYD India, Hyundai Motor from 2022-24

# %%
top_5_ev_seller = pivote_table.sort_values(by='total_sales',ascending=False).head()

# %%
top_5_ev_seller
# Out:
# year                maker   2022   2023   2024  total_sales
# 8             Tata Motors  24352  40348  17361        82061
# 5     Mahindra & Mahindra  10215  26273   2316        38804
# 4                MG Motor   2484   7153   2622        12259
# 1               BYD India    329   1689    400         2418
# 2           Hyundai Motor    447   1207    338         1992

# %%
ev_makers_tata_motors = ev_makers[(ev_makers['maker']=='Tata Motors')]
ev_makers_tata_motors
# Out:
#           date vehicle_category        maker  electric_vehicles_sold  month  \
# 88  2021-04-01       4-Wheelers  Tata Motors                     322      4
# 93  2022-04-01       4-Wheelers  Tata Motors                    1409      4
# 100 2023-04-01       4-Wheelers  Tata Motors                     364      4
# 110 2021-05-01       4-Wheelers  Tata Motors                     137      5
# 114 2022-05-01       4-Wheelers  Tata Motors                    2097      5
# 121 2023-05-01       4-Wheelers  Tata Motors                    3212      5
# 131 2021-06-01       4-Wheelers  Tata Motors                     572      6
# 136 2022-06-01       4-Wheelers  Tata Motors                    2169      6
# 143 2023-06-01       4-Wheelers  Tata Motors                    3671      6
# 153 2021-07-01       4-Wheelers  Tata Motors                     696      7
# 158 2022-07-01       4-Wheelers  Tata Motors                    2264      7
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,8))

sns.lineplot(x=ev_makers_tata_motors['date'], y = ev_makers_tata_motors['electric_vehicles_sold'])

plt.xticks(rotation=90)
# Out:
# (array([18748., 18871., 18993., 19113., 19236., 19358., 19478., 19601.,
#         19723.]),
#  [Text(18748.0, 0, '2021-05'),
#   Text(18871.0, 0, '2021-09'),
#   Text(18993.0, 0, '2022-01'),
#   Text(19113.0, 0, '2022-05'),
#   Text(19236.0, 0, '2022-09'),
#   Text(19358.0, 0, '2023-01'),
#   Text(19478.0, 0, '2023-05'),
#   Text(19601.0, 0, '2023-09'),
#   Text(19723.0, 0, '2024-01')])

# %%
ev_makers_mahindra = ev_makers[(ev_makers['maker']=='Mahindra & Mahindra')]
ev_makers_mahindra
# Out:
#           date vehicle_category                maker  electric_vehicles_sold  \
# 90  2021-04-01       4-Wheelers  Mahindra & Mahindra                     171
# 95  2022-04-01       4-Wheelers  Mahindra & Mahindra                     611
# 102 2023-04-01       4-Wheelers  Mahindra & Mahindra                    4880
# 112 2021-05-01       4-Wheelers  Mahindra & Mahindra                      78
# 116 2022-05-01       4-Wheelers  Mahindra & Mahindra                     622
# 123 2023-05-01       4-Wheelers  Mahindra & Mahindra                    3457
# 133 2021-06-01       4-Wheelers  Mahindra & Mahindra                     106
# 138 2022-06-01       4-Wheelers  Mahindra & Mahindra                     787
# 145 2023-06-01       4-Wheelers  Mahindra & Mahindra                    2574
# 155 2021-07-01       4-Wheelers  Mahindra & Mahindra                     171
# 160 2022-07-01       4-Wheelers  Mahindra & Mahindra                     866
# ...

# %%
plt.figure(figsize=(20,8))

sns.lineplot(x=ev_makers_mahindra['date'], y = ev_makers_mahindra['electric_vehicles_sold'])

plt.xticks(rotation=90)
# Out:
# (array([18748., 18871., 18993., 19113., 19236., 19358., 19478., 19601.,
#         19723.]),
#  [Text(18748.0, 0, '2021-05'),
#   Text(18871.0, 0, '2021-09'),
#   Text(18993.0, 0, '2022-01'),
#   Text(19113.0, 0, '2022-05'),
#   Text(19236.0, 0, '2022-09'),
#   Text(19358.0, 0, '2023-01'),
#   Text(19478.0, 0, '2023-05'),
#   Text(19601.0, 0, '2023-09'),
#   Text(19723.0, 0, '2024-01')])

# %%
ev_makers_mg_motor = ev_makers[(ev_makers['maker']=='MG Motor')]
ev_makers_mg_motor
# Out:
#           date vehicle_category     maker  electric_vehicles_sold  month  \
# 89  2021-04-01       4-Wheelers  MG Motor                     118      4
# 94  2022-04-01       4-Wheelers  MG Motor                     177      4
# 101 2023-04-01       4-Wheelers  MG Motor                     265      4
# 111 2021-05-01       4-Wheelers  MG Motor                      39      5
# 115 2022-05-01       4-Wheelers  MG Motor                     181      5
# 122 2023-05-01       4-Wheelers  MG Motor                     351      5
# 132 2021-06-01       4-Wheelers  MG Motor                     128      6
# 137 2022-06-01       4-Wheelers  MG Motor                     173      6
# 144 2023-06-01       4-Wheelers  MG Motor                     877      6
# 154 2021-07-01       4-Wheelers  MG Motor                     232      7
# 159 2022-07-01       4-Wheelers  MG Motor                     194      7
# 166 2023-07-01       4-Wheelers  MG Motor                     935      7
# ...

# %%
plt.figure(figsize=(20,8))

sns.lineplot(x=ev_makers_mg_motor['date'], y = ev_makers_mg_motor['electric_vehicles_sold'])

plt.xticks(rotation=90)
# Out:
# (array([18748., 18871., 18993., 19113., 19236., 19358., 19478., 19601.,
#         19723.]),
#  [Text(18748.0, 0, '2021-05'),
#   Text(18871.0, 0, '2021-09'),
#   Text(18993.0, 0, '2022-01'),
#   Text(19113.0, 0, '2022-05'),
#   Text(19236.0, 0, '2022-09'),
#   Text(19358.0, 0, '2023-01'),
#   Text(19478.0, 0, '2023-05'),
#   Text(19601.0, 0, '2023-09'),
#   Text(19723.0, 0, '2024-01')])

# %%
ev_makers_byd_india = ev_makers[(ev_makers['maker']=='BYD India')]
ev_makers_byd_india
# Out:
#           date vehicle_category      maker  electric_vehicles_sold  month  \
# 9   2021-04-01       4-Wheelers  BYD India                       0      4
# 17  2021-05-01       4-Wheelers  BYD India                       0      5
# 26  2021-06-01       4-Wheelers  BYD India                       0      6
# 34  2021-07-01       4-Wheelers  BYD India                       0      7
# 42  2021-08-01       4-Wheelers  BYD India                       0      8
# 50  2021-09-01       4-Wheelers  BYD India                       0      9
# 58  2021-10-01       4-Wheelers  BYD India                       0     10
# 65  2021-11-01       4-Wheelers  BYD India                       0     11
# 96  2022-04-01       4-Wheelers  BYD India                      15      4
# 103 2023-04-01       4-Wheelers  BYD India                     156      4
# 117 2022-05-01       4-Wheelers  BYD India                      30      5
# 124 2023-05-01       4-Wheelers  BYD India                     110      5
# ...

# %%
plt.figure(figsize=(20,8))

sns.lineplot(x=ev_makers_byd_india['date'], y = ev_makers_byd_india['electric_vehicles_sold'])

plt.xticks(rotation=90)
# Out:
# (array([18748., 18871., 18993., 19113., 19236., 19358., 19478., 19601.,
#         19723.]),
#  [Text(18748.0, 0, '2021-05'),
#   Text(18871.0, 0, '2021-09'),
#   Text(18993.0, 0, '2022-01'),
#   Text(19113.0, 0, '2022-05'),
#   Text(19236.0, 0, '2022-09'),
#   Text(19358.0, 0, '2023-01'),
#   Text(19478.0, 0, '2023-05'),
#   Text(19601.0, 0, '2023-09'),
#   Text(19723.0, 0, '2024-01')])

# %%
ev_makers_hyundai_motor = ev_makers[(ev_makers['maker']=='Hyundai Motor')]
ev_makers_hyundai_motor.sort_values(by='date', ascending=True)
# Out:
#           date vehicle_category          maker  electric_vehicles_sold  month  \
# 91  2021-04-01       4-Wheelers  Hyundai Motor                      12      4
# 113 2021-05-01       4-Wheelers  Hyundai Motor                       3      5
# 134 2021-06-01       4-Wheelers  Hyundai Motor                      10      6
# 156 2021-07-01       4-Wheelers  Hyundai Motor                      18      7
# 178 2021-08-01       4-Wheelers  Hyundai Motor                      10      8
# 200 2021-09-01       4-Wheelers  Hyundai Motor                       6      9
# 222 2021-10-01       4-Wheelers  Hyundai Motor                       8     10
# 245 2021-11-01       4-Wheelers  Hyundai Motor                       7     11
# 270 2021-12-01       4-Wheelers  Hyundai Motor                      10     12
# 295 2022-01-01       4-Wheelers  Hyundai Motor                       6      1
# 320 2022-02-01       4-Wheelers  Hyundai Motor                       6      2
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,8))
sns.lineplot(x=ev_makers_hyundai_motor['date'], y = ev_makers_hyundai_motor['electric_vehicles_sold'])
plt.xticks(rotation=90)
# Out:
# (array([18748., 18871., 18993., 19113., 19236., 19358., 19478., 19601.,
#         19723.]),
#  [Text(18748.0, 0, '2021-05'),
#   Text(18871.0, 0, '2021-09'),
#   Text(18993.0, 0, '2022-01'),
#   Text(19113.0, 0, '2022-05'),
#   Text(19236.0, 0, '2022-09'),
#   Text(19358.0, 0, '2023-01'),
#   Text(19478.0, 0, '2023-05'),
#   Text(19601.0, 0, '2023-09'),
#   Text(19723.0, 0, '2024-01')])

# %%
plt.figure(figsize=(20,8))
sns.lineplot(x=ev_makers_hyundai_motor['date'], y = ev_makers_hyundai_motor['electric_vehicles_sold'], label='Hyundai Motors')
sns.lineplot(x=ev_makers_byd_india['date'], y = ev_makers_byd_india['electric_vehicles_sold'], label='BYD India')
sns.lineplot(x=ev_makers_mg_motor['date'], y = ev_makers_mg_motor['electric_vehicles_sold'], label = 'MG Motors')
sns.lineplot(x=ev_makers_mahindra['date'], y = ev_makers_mahindra['electric_vehicles_sold'], label='Mahindra')
sns.lineplot(x=ev_makers_tata_motors['date'], y = ev_makers_tata_motors['electric_vehicles_sold'], label='Tata Motors')

plt.xticks(rotation=90)
# Out:
# (array([18748., 18871., 18993., 19113., 19236., 19358., 19478., 19601.,
#         19723.]),
#  [Text(18748.0, 0, '2021-05'),
#   Text(18871.0, 0, '2021-09'),
#   Text(18993.0, 0, '2022-01'),
#   Text(19113.0, 0, '2022-05'),
#   Text(19236.0, 0, '2022-09'),
#   Text(19358.0, 0, '2023-01'),
#   Text(19478.0, 0, '2023-05'),
#   Text(19601.0, 0, '2023-09'),
#   Text(19723.0, 0, '2024-01')])

# %% [markdown]
# # Question 04:-
# ### Trend for each of one 5 top ev sellers for the year 2022-24

# %%
df5 = ev_states.copy()

# %%
df5_filtered = df5[df5['year']==2024]

# %%
df5_filtered_delhi = df5_filtered[df5['state']=='Delhi']
df5_filtered_delhi
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_7588\891192427.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df5_filtered_delhi = df5_filtered[df5['state']=='Delhi']
#            date  state vehicle_category  electric_vehicles_sold  \
# 1370 2024-01-01  Delhi       4-Wheelers                    1345
# 1400 2024-02-01  Delhi       4-Wheelers                     596
# 1425 2024-03-01  Delhi       4-Wheelers                     897
# 2361 2024-01-01  Delhi       2-Wheelers                    3073
# 2394 2024-02-01  Delhi       2-Wheelers                    2364
# 2420 2024-03-01  Delhi       2-Wheelers                    5002
#
#       total_vehicles_sold  month  year quarter  penetration_rate
# 1370                21520      1  2024      Q4          6.250000
# 1400                17898      2  2024      Q4          3.329981
# 1425                15905      3  2024      Q4          5.639736
# ...

# %%
df5_filtered_karnataka = df5_filtered[df5['state']=='Karnataka']
df5_filtered_karnataka
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_7588\3610906211.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df5_filtered_karnataka = df5_filtered[df5['state']=='Karnataka']
#            date      state vehicle_category  electric_vehicles_sold  \
# 1365 2024-01-01  Karnataka       4-Wheelers                    1080
# 1393 2024-02-01  Karnataka       4-Wheelers                     923
# 1422 2024-03-01  Karnataka       4-Wheelers                    1482
# 2356 2024-01-01  Karnataka       2-Wheelers                   12415
# 2387 2024-02-01  Karnataka       2-Wheelers                   12605
# 2417 2024-03-01  Karnataka       2-Wheelers                   22742
#
#       total_vehicles_sold  month  year quarter  penetration_rate
# 1365                30770      1  2024      Q4          3.509912
# 1393                24812      2  2024      Q4          3.719974
# 1422                26751      3  2024      Q4          5.539980
# ...

# %%
df5_delhi_karnataka = df5_filtered[df5_filtered['state'].isin(['Delhi', 'Karnataka'])]
df5_ = df5_delhi_karnataka.sort_values(by='date').sort_values(by='vehicle_category')

# %%
df5_[['state','vehicle_category','electric_vehicles_sold','penetration_rate']]
# Out:
#           state vehicle_category  electric_vehicles_sold  penetration_rate
# 2356  Karnataka       2-Wheelers                   12415         10.709972
# 2361      Delhi       2-Wheelers                    3073          7.999896
# 2387  Karnataka       2-Wheelers                   12605         11.579943
# 2394      Delhi       2-Wheelers                    2364          7.749803
# 2417  Karnataka       2-Wheelers                   22742         18.369952
# 2420      Delhi       2-Wheelers                    5002         15.829615
# 1365  Karnataka       4-Wheelers                    1080          3.509912
# 1370      Delhi       4-Wheelers                    1345          6.250000
# 1393  Karnataka       4-Wheelers                     923          3.719974
# 1400      Delhi       4-Wheelers                     596          3.329981
# 1422  Karnataka       4-Wheelers                    1482          5.539980
# ...

# %% [markdown]
# # Question 05:-
# ##  How do the EV sales and penetration rates in Delhi compare to Karnataka for 2024?

# %%
top_5_ev_seller['cagr'] = ((top_5_ev_seller[2022]/top_5_ev_seller[2024]) ** 1/2) -1

# %%
top_5_ev_seller
# Out:
# year                maker   2022   2023   2024  total_sales      cagr
# 8             Tata Motors  24352  40348  17361        82061 -0.298658
# 5     Mahindra & Mahindra  10215  26273   2316        38804  1.205311
# 4                MG Motor   2484   7153   2622        12259 -0.526316
# 1               BYD India    329   1689    400         2418 -0.588750
# 2           Hyundai Motor    447   1207    338         1992 -0.338757

# %% [markdown]
# # Question 06:-
# ## List down the compounded annual growth rate (CAGR) in 4-wheeler units for the top 5 makers from 2022 to 2024.

# %% [markdown]
# # Question 07:-
# ## List down the top 10 states that had the highest compounded annual growth rate (CAGR) from 2022 to 2024 in total vehicles sold.

# %%
ev_states.columns
# Out:
# Index(['date', 'state', 'vehicle_category', 'electric_vehicles_sold',
#        'total_vehicles_sold', 'month', 'year', 'quarter', 'penetration_rate'],
#       dtype='object')

# %%
(ev_states['state'].unique())
# Out:
# array(['Sikkim', 'Andaman & Nicobar Island', 'Arunachal Pradesh', 'Assam',
#        'Chhattisgarh', 'DNH and DD', 'Jammu and Kashmir', 'Ladakh',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Puducherry',
#        'Tripura', 'Bihar', 'Chandigarh', 'Delhi', 'Madhya Pradesh',
#        'Odisha', 'Punjab', 'Uttarakhand', 'Himachal Pradesh',
#        'Andaman & Nicobar', 'Haryana', 'Jharkhand', 'Andhra Pradesh',
#        'Goa', 'Gujarat', 'Karnataka', 'Kerala', 'Maharashtra',
#        'Rajasthan', 'Tamil Nadu', 'Uttar Pradesh', 'West Bengal'],
#       dtype=object)

# %%
df7 = ev_states.copy()

# %%
df7_filtered = df7[df7['year'].isin([2022,2023,2024])]

# %%
df7_grouped_data = df7_filtered.groupby(['state','year'])['electric_vehicles_sold'].sum().reset_index()

# %%
df7_grouped_data
# Out:
#                         state  year  electric_vehicles_sold
# 0           Andaman & Nicobar  2024                       2
# 1    Andaman & Nicobar Island  2022                      23
# 2    Andaman & Nicobar Island  2023                      26
# 3    Andaman & Nicobar Island  2024                       9
# 4              Andhra Pradesh  2022                   28050
# ..                        ...   ...                     ...
# 98                Uttarakhand  2023                    6176
# 99                Uttarakhand  2024                    1707
# 100               West Bengal  2022                    9363
# 101               West Bengal  2023                   14031
# 102               West Bengal  2024                    6000
#
# [103 rows x 3 columns]

# %%
df7_pivot_table = df7_grouped_data.pivot(index='state', columns='year', values='electric_vehicles_sold').reset_index()

# %%
df7_pivot_table
# Out:
# year                     state      2022      2023     2024
# 0            Andaman & Nicobar       NaN       NaN      2.0
# 1     Andaman & Nicobar Island      23.0      26.0      9.0
# 2               Andhra Pradesh   28050.0   30057.0  12638.0
# 3            Arunachal Pradesh       2.0      21.0     10.0
# 4                        Assam    1984.0    2724.0   1364.0
# 5                        Bihar   10071.0   12980.0   5401.0
# 6                   Chandigarh    1129.0    3104.0    763.0
# 7                 Chhattisgarh   16760.0   26264.0   8485.0
# 8                   DNH and DD     103.0     142.0     92.0
# 9                        Delhi   40238.0   45699.0  13277.0
# 10                         Goa    5616.0    9290.0   3875.0
# 11                     Gujarat   67388.0   85072.0  20688.0
# 12                     Haryana   12529.0   10088.0   4620.0
# 13            Himachal Pradesh     988.0    1039.0    276.0
# 14           Jammu and Kashmir    2180.0    1971.0    801.0
# ...

# %%
df7_pivot_table['total_ev_sold'] = df7_pivot_table[2022]+df7_pivot_table[2023]+df7_pivot_table[2024]

# %%
df7_pivot_table = df7_pivot_table.fillna(0)
df7_pivot_table
# Out:
# year                     state      2022      2023     2024  total_ev_sold
# 0            Andaman & Nicobar       0.0       0.0      2.0            0.0
# 1     Andaman & Nicobar Island      23.0      26.0      9.0           58.0
# 2               Andhra Pradesh   28050.0   30057.0  12638.0        70745.0
# 3            Arunachal Pradesh       2.0      21.0     10.0           33.0
# 4                        Assam    1984.0    2724.0   1364.0         6072.0
# 5                        Bihar   10071.0   12980.0   5401.0        28452.0
# 6                   Chandigarh    1129.0    3104.0    763.0         4996.0
# 7                 Chhattisgarh   16760.0   26264.0   8485.0        51509.0
# 8                   DNH and DD     103.0     142.0     92.0          337.0
# 9                        Delhi   40238.0   45699.0  13277.0        99214.0
# 10                         Goa    5616.0    9290.0   3875.0        18781.0
# ...

# %%
df7_pivot_table['cagr'] = ((df7_pivot_table[2022]/df7_pivot_table[2024])**1/2) -1

# %%
df7_pivot_table.sort_values(by='cagr', ascending=False).head(10)
# Out:
# year              state     2022     2023     2024  total_ev_sold      cagr
# 13     Himachal Pradesh    988.0   1039.0    276.0         2303.0  0.789855
# 33          Uttarakhand   6081.0   6176.0   1707.0        13964.0  0.781195
# 25               Odisha  26159.0  39688.0   7969.0        73816.0  0.641298
# 11              Gujarat  67388.0  85072.0  20688.0       173148.0  0.628674
# 21              Manipur    126.0    119.0     39.0          284.0  0.615385
# 15            Jharkhand   6887.0   7852.0   2208.0        16947.0  0.559556
# 9                 Delhi  40238.0  45699.0  13277.0        99214.0  0.515327
# 28            Rajasthan  55600.0  63960.0  19018.0       138578.0  0.461773
# 14    Jammu and Kashmir   2180.0   1971.0    801.0         4952.0  0.360799
# 12              Haryana  12529.0  10088.0   4620.0        27237.0  0.355952

# %% [markdown]
# ### Top 10 states with highest cagr values are for the year 2022-24
# 1. Himachal Pradesh
# 2. Uttrakhand
# 3. Odisha
# 4. Gujarat
# 5. Manipur
# 6. Jharkhand
# 7. Delhi
# 8. Rajasthan
# 9. Jammu and Kashmir
# 10. Haryana

# %%
df8 = ev_states[ev_states['year'].isin([2022,2023,2024])]

# %%
df8_2_wheelers = ev_states[ev_states['vehicle_category']=='2-Wheelers']

# %%
df8_2_wheelers
# Out:
#            date                     state vehicle_category  \
# 0    2021-04-01                    Sikkim       2-Wheelers
# 2    2021-05-01                    Sikkim       2-Wheelers
# 4    2021-06-01                    Sikkim       2-Wheelers
# 6    2021-07-01                    Sikkim       2-Wheelers
# 8    2021-08-01                    Sikkim       2-Wheelers
# ...         ...                       ...              ...
# 2440 2024-03-01                   Mizoram       2-Wheelers
# 2441 2024-03-01                DNH and DD       2-Wheelers
# 2442 2024-03-01                   Manipur       2-Wheelers
# 2443 2024-03-01  Andaman & Nicobar Island       2-Wheelers
# 2444 2024-03-01                  Nagaland       2-Wheelers
#
#       electric_vehicles_sold  total_vehicles_sold  month  year quarter  \
# 0                          0                  398      4  2021      Q1
# 2                          0                  113      5  2021      Q1
# ...

# %%
monthly_sales_2_wheelers = df8_2_wheelers.groupby('month')['electric_vehicles_sold'].sum().reset_index()

# %%
#  Step 3: Find the peak and low season months based on total EV sales
peak_month_2_wheelers = monthly_sales_2_wheelers.loc[monthly_sales_2_wheelers['electric_vehicles_sold'].idxmax()]
low_month_2_wheelers = monthly_sales_2_wheelers.loc[monthly_sales_2_wheelers['electric_vehicles_sold'].idxmin()]

# %%
peak_month_2_wheelers
# Out:
# month                          3
# electric_vehicles_sold    270309
# Name: 2, dtype: int64

# %%
low_month_2_wheelers
# Out:
# month                         6
# electric_vehicles_sold    94891
# Name: 5, dtype: int64

# %% [markdown]
# ### Question 08:-
# 1. Peak month for 2 wheelers ev's is March
# 2. low month for 2 wheelers ev's is Jun

# %%
plt.figure(figsize=(20,8))
sns.lineplot(x=monthly_sales_2_wheelers['month'], y = monthly_sales_2_wheelers['electric_vehicles_sold'])
plt.xticks(rotation=90)
# Out:
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12., 14.]),
#  [Text(0.0, 0, '0'),
#   Text(2.0, 0, '2'),
#   Text(4.0, 0, '4'),
#   Text(6.0, 0, '6'),
#   Text(8.0, 0, '8'),
#   Text(10.0, 0, '10'),
#   Text(12.0, 0, '12'),
#   Text(14.0, 0, '14')])

# %%
monthly_sales_2_wheelers
# Out:
#     month  electric_vehicles_sold
# 0       1                  176143
# 1       2                  183756
# 2       3                  270309
# 3       4                  125778
# 4       5                  149013
# 5       6                   94891
# 6       7                  115472
# 7       8                  130747
# 8       9                  135060
# 9      10                  172686
# 10     11                  192552
# 11     12                  166761

# %%
df8_4_wheelers = df8[df8['vehicle_category']=='4-Wheelers']

# %%
df8_4_wheelers
# Out:
#            date             state vehicle_category  electric_vehicles_sold  \
# 19   2022-01-01            Sikkim       4-Wheelers                       0
# 21   2022-02-01            Sikkim       4-Wheelers                       0
# 23   2022-03-01            Sikkim       4-Wheelers                       0
# 25   2022-04-01            Sikkim       4-Wheelers                       0
# 27   2022-05-01            Sikkim       4-Wheelers                       0
# ...         ...               ...              ...                     ...
# 1442 2024-03-01        Puducherry       4-Wheelers                       5
# 1443 2024-03-01         Meghalaya       4-Wheelers                       3
# 1444 2024-03-01  Himachal Pradesh       4-Wheelers                      17
# 1445 2024-03-01        DNH and DD       4-Wheelers                       4
# 1446 2024-03-01           Manipur       4-Wheelers                       2
#
#       total_vehicles_sold  month  year quarter  penetration_rate
# ...

# %%
monthly_sales_4_wheelers = df8_4_wheelers.groupby('month')['electric_vehicles_sold'].sum().reset_index()

# %%
#  Step 3: Find the peak and low season months based on total EV sales
peak_month_4_wheelers = monthly_sales_4_wheelers.loc[monthly_sales_4_wheelers['electric_vehicles_sold'].idxmax()]
low_month_4_wheelers = monthly_sales_4_wheelers.loc[monthly_sales_4_wheelers['electric_vehicles_sold'].idxmin()]

# %%
monthly_sales_4_wheelers
# Out:
#     month  electric_vehicles_sold
# 0       1                   12956
# 1       2                   14293
# 2       3                   21278
# 3       4                    8253
# 4       5                   10599
# 5       6                   11000
# 6       7                   10836
# 7       8                   10111
# 8       9                    9593
# 9      10                   11122
# 10     11                   11019
# 11     12                   11025

# %%
peak_month_4_wheelers
# Out:
# month                         3
# electric_vehicles_sold    21278
# Name: 2, dtype: int64

# %%
low_month_4_wheelers
# Out:
# month                        4
# electric_vehicles_sold    8253
# Name: 3, dtype: int64

# %% [markdown]
# ### Question 08:-
# 1. Peak month for 4 wheelers ev's is March
# 2. low month for 4 wheelers ev's is April

# %%
plt.figure(figsize=(20,8))
sns.lineplot(x=monthly_sales_4_wheelers['month'], y = monthly_sales_4_wheelers['electric_vehicles_sold'], label='4-Wheelers')

plt.xticks(rotation=90)
# Out:
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12., 14.]),
#  [Text(0.0, 0, '0'),
#   Text(2.0, 0, '2'),
#   Text(4.0, 0, '4'),
#   Text(6.0, 0, '6'),
#   Text(8.0, 0, '8'),
#   Text(10.0, 0, '10'),
#   Text(12.0, 0, '12'),
#   Text(14.0, 0, '14')])

# %% [markdown]
# ## Question 09:-

# %%
df9 = ev_states.copy()

# %%
df9
# Out:
#            date                     state vehicle_category  \
# 0    2021-04-01                    Sikkim       2-Wheelers
# 1    2021-04-01                    Sikkim       4-Wheelers
# 2    2021-05-01                    Sikkim       2-Wheelers
# 3    2021-05-01                    Sikkim       4-Wheelers
# 4    2021-06-01                    Sikkim       2-Wheelers
# ...         ...                       ...              ...
# 2440 2024-03-01                   Mizoram       2-Wheelers
# 2441 2024-03-01                DNH and DD       2-Wheelers
# 2442 2024-03-01                   Manipur       2-Wheelers
# 2443 2024-03-01  Andaman & Nicobar Island       2-Wheelers
# 2444 2024-03-01                  Nagaland       2-Wheelers
#
#       electric_vehicles_sold  total_vehicles_sold  month  year quarter  \
# 0                          0                  398      4  2021      Q1
# 1                          0                  361      4  2021      Q1
# ...

# %%
df9_2023 = df9[df9['year']==2023]
df9_2023_2_wheelers = df9_2023[df9_2023['vehicle_category']=='2-Wheelers']

# %%
df9_2023
# Out:
#            date          state vehicle_category  electric_vehicles_sold  \
# 42   2023-01-01         Sikkim       2-Wheelers                       0
# 43   2023-01-01         Sikkim       4-Wheelers                       0
# 44   2023-02-01         Sikkim       2-Wheelers                       0
# 45   2023-02-01         Sikkim       4-Wheelers                       0
# 46   2023-03-01         Sikkim       2-Wheelers                       0
# ...         ...            ...              ...                     ...
# 2349 2023-12-01     Tamil Nadu       2-Wheelers                    5403
# 2350 2023-12-01        Tripura       2-Wheelers                      40
# 2351 2023-12-01  Uttar Pradesh       2-Wheelers                    5487
# 2352 2023-12-01    Uttarakhand       2-Wheelers                     655
# 2353 2023-12-01    West Bengal       2-Wheelers                    2625
#
#       total_vehicles_sold  month  year quarter  penetration_rate
# ...

# %%
df9_2023_2_wheelers.sort_values(by='month')
# Out:
#            date           state vehicle_category  electric_vehicles_sold  \
# 66   2024-01-01          Sikkim       2-Wheelers                       0
# 2367 2024-01-01    Chhattisgarh       2-Wheelers                    2367
# 2368 2024-01-01     West Bengal       2-Wheelers                    1636
# 2370 2024-01-01  Andhra Pradesh       2-Wheelers                    2134
# 2371 2024-01-01       Jharkhand       2-Wheelers                     551
# ...         ...             ...              ...                     ...
# 2423 2024-03-01           Bihar       2-Wheelers                    2584
# 2424 2024-03-01  Madhya Pradesh       2-Wheelers                    5772
# 2425 2024-03-01  Andhra Pradesh       2-Wheelers                    7057
# 2418 2024-03-01      Tamil Nadu       2-Wheelers                   13350
# 2444 2024-03-01        Nagaland       2-Wheelers                       2
#
#       total_vehicles_sold  month  year quarter  penetration_rate
# ...

# %%
df9_2023_4_wheelers = df9_2023[df9_2023['vehicle_category']=='4-Wheelers']
df9_2023_4_wheelers.sort_values(by='month')
# Out:
#            date           state vehicle_category  electric_vehicles_sold  \
# 43   2023-01-01          Sikkim       4-Wheelers                       0
# 1035 2023-01-01  Andhra Pradesh       4-Wheelers                     121
# 1037 2023-01-01           Bihar       4-Wheelers                      19
# 1038 2023-01-01      Chandigarh       4-Wheelers                      50
# 1039 2023-01-01    Chhattisgarh       4-Wheelers                      56
# ...         ...             ...              ...                     ...
# 1340 2023-12-01    Chhattisgarh       4-Wheelers                      93
# 1341 2023-12-01      DNH and DD       4-Wheelers                       5
# 1342 2023-12-01           Delhi       4-Wheelers                     811
# 1335 2023-12-01  Andhra Pradesh       4-Wheelers                     130
# 1362 2023-12-01     West Bengal       4-Wheelers                     160
#
#       total_vehicles_sold  month  year quarter  penetration_rate
# ...

# %%
df9_2022 = df9[df9['year']==2022]
df9_2022_2_wheelers = df9_2022[df9_2022['vehicle_category']=='2-Wheelers']

# %%
df9_2022_4_wheelers = df9_2022[df9_2022['vehicle_category']=='4-Wheelers']

# %%
df9_2022_2_wheelers.sort_values(by='month')
# Out:
#            date         state vehicle_category  electric_vehicles_sold  \
# 18   2022-01-01        Sikkim       2-Wheelers                       0
# 1670 2022-01-01         Bihar       2-Wheelers                     409
# 1671 2022-01-01    Chandigarh       2-Wheelers                      19
# 1672 2022-01-01  Chhattisgarh       2-Wheelers                     595
# 1673 2022-01-01    DNH and DD       2-Wheelers                       6
# ...         ...           ...              ...                     ...
# 1983 2022-12-01    DNH and DD       2-Wheelers                      19
# 1984 2022-12-01         Delhi       2-Wheelers                    3826
# 1985 2022-12-01           Goa       2-Wheelers                     528
# 1979 2022-12-01         Assam       2-Wheelers                     250
# 2005 2022-12-01   West Bengal       2-Wheelers                    1047
#
#       total_vehicles_sold  month  year quarter  penetration_rate
# ...

# %%
df9_2022_4_wheelers.sort_values(by='month')
# Out:
#            date          state vehicle_category  electric_vehicles_sold  \
# 19   2022-01-01         Sikkim       4-Wheelers                       0
# 764  2022-01-01    West Bengal       4-Wheelers                      54
# 763  2022-01-01    Uttarakhand       4-Wheelers                      30
# 762  2022-01-01  Uttar Pradesh       4-Wheelers                      14
# 761  2022-01-01     Tamil Nadu       4-Wheelers                     121
# ...         ...            ...              ...                     ...
# 1012 2022-12-01          Assam       4-Wheelers                       4
# 1013 2022-12-01          Bihar       4-Wheelers                       5
# 1014 2022-12-01     Chandigarh       4-Wheelers                      46
# 368  2022-12-01        Mizoram       4-Wheelers                       0
# 1034 2022-12-01    West Bengal       4-Wheelers                      65
#
#       total_vehicles_sold  month  year quarter  penetration_rate
# ...

# %%
df9_2023_4_wheelers.groupby('state')['penetration_rate'].mean().sort_values(ascending=False)
# Out:
# state
# Kerala                      4.938451
# Delhi                       4.125639
# Goa                         3.973872
# Karnataka                   3.950469
# Chandigarh                  3.927112
# Maharashtra                 2.963996
# West Bengal                 2.451797
# Tamil Nadu                  2.335299
# Chhattisgarh                2.331643
# Rajasthan                   2.271597
# Gujarat                     1.903341
# Andhra Pradesh              1.806233
# Odisha                      1.730825
# Uttar Pradesh               1.186341
# Haryana                     1.038051
# Madhya Pradesh              0.956585
# Uttarakhand                 0.882673
# Bihar                       0.830968
# Puducherry                  0.830239
# Jharkhand                   0.823732
# Manipur                     0.799451
# DNH and DD                  0.745943
# Andaman & Nicobar Island    0.715201
# Tripura                     0.600133
# Punjab                      0.551140
# ...

# %% [markdown]
# ### Top 10 states by penetration for 4-wheelers vehicles
# Kerala                      4.938451
# Delhi                       4.125639
# Goa                         3.973872
# Karnataka                   3.950469
# Chandigarh                  3.927112
# Maharashtra                 2.963996
# West Bengal                 2.451797
# Tamil Nadu                  2.335299
# Chhattisgarh                2.331643
# Rajasthan                   2.271597
# Gujarat                     1.903341

# %%
df9_2023_2_wheelers.groupby('state')['penetration_rate'].mean().sort_values(ascending=False)
# Out:
# state
# Goa                         23.986226
# Kerala                      16.266559
# Karnataka                   13.553289
# Ladakh                      12.612613
# Maharashtra                 12.413312
# Delhi                       10.526438
# Chandigarh                  10.378199
# Puducherry                   8.485596
# Tamil Nadu                   7.236649
# Rajasthan                    6.939941
# Odisha                       6.889967
# Gujarat                      6.876614
# Andhra Pradesh               6.396620
# Chhattisgarh                 6.279948
# Madhya Pradesh               4.873326
# Jammu and Kashmir            4.629623
# Uttarakhand                  4.059879
# Uttar Pradesh                3.333326
# Punjab                       3.209946
# Haryana                      3.026612
# DNH and DD                   3.022058
# West Bengal                  2.386649
# Mizoram                      2.291437
# Jharkhand                    2.006614
# ...

# %% [markdown]
# ### Top 10 states by penetration for 2-wheelers vehicles
# 1. Goa                         23.986226
# 2. Kerala                      16.266559
# 3. Karnataka                   13.553289
# 4. Ladakh                      12.612613
# 5. Maharashtra                 12.413312
# 6. Delhi                       10.526438
# 7. Chandigarh                  10.378199
# 8. Puducherry                   8.485596
# 9. Tamil Nadu                   7.236649
# 10. Rajasthan                    6.939941

# %%
monthly_sales_2022 = df8[df8['year']==2022]
monthly_sales_2023 = df8[df8['year']==2023]
monthly_sales_2024 = df8[df8['year']==2024]

# %%
monthly_sales_2022 = monthly_sales_2022.groupby('month')['electric_vehicles_sold'].sum().reset_index()
monthly_sales_2023 = monthly_sales_2023.groupby('month')['electric_vehicles_sold'].sum().reset_index()
monthly_sales_2024 = monthly_sales_2024.groupby('month')['electric_vehicles_sold'].sum().reset_index()

# %%
print(monthly_sales_2022)
# Out:
#     month  electric_vehicles_sold
# 0       1                   31672
# 1       2                   38171
# 2       3                   58118
# 3       4                   55524
# 4       5                   45373
# 5       6                   47591
# 6       7                   50010
# 7       8                   55584
# 8       9                   56828
# 9      10                   81162
# 10     11                   80752
# 11     12                   68475

# %%
print(monthly_sales_2023)
# Out:
#     month  electric_vehicles_sold
# 0       1                   68116
# 1       2                   70827
# 2       3                   95126
# 3       4                   72818
# 4       5                  112997
# 5       6                   53631
# 6       7                   61622
# 7       8                   69224
# 8       9                   69793
# 9      10                   81833
# 10     11                   98285
# 11     12                   82685

# %%
print(monthly_sales_2024)
# Out:
#    month  electric_vehicles_sold
# 0      1                   89311
# 1      2                   89051
# 2      3                  138343

# %%
plt.figure(figsize=(20,8))
sns.lineplot(x=monthly_sales_2022['month'], y = monthly_sales_2022['electric_vehicles_sold'], label='2022')
sns.lineplot(x=monthly_sales_2023['month'], y=monthly_sales_2023['electric_vehicles_sold'], label='2023')
sns.lineplot(x=monthly_sales_2024['month'], y = monthly_sales_2024['electric_vehicles_sold'], label='2024')
plt.xticks(rotation=90)
# Out:
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12., 14.]),
#  [Text(0.0, 0, '0'),
#   Text(2.0, 0, '2'),
#   Text(4.0, 0, '4'),
#   Text(6.0, 0, '6'),
#   Text(8.0, 0, '8'),
#   Text(10.0, 0, '10'),
#   Text(12.0, 0, '12'),
#   Text(14.0, 0, '14')])

# %% [markdown]
# ## Adding year and month column in ev_makers
